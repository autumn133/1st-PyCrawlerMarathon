# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup
import re
import requests.packages.urllib3

requests.packages.urllib3.disable_warnings()

# %%
# 未登入無權限時
res = requests.get('https://github.com/new', verify=False)
soup = BeautifulSoup(res.text,'html.parser')
print(*(x for x in list(filter(None, [x.strip() for x in soup.text.split('\n') if x]))), sep='\n')
# Out:
# Sign in to GitHub · GitHub
# Skip to content
# GitHub no longer supports this web browser.
# Learn more about the browsers we support.
# Sign in to GitHub
# Username or email address
# Password Forgot password?
# New to GitHub?
# Create an account.
# Terms
# Privacy
# Security
# Contact GitHub
# You can’t perform that action at this time.
# You signed in with another tab or window. Reload to refresh your session.
# You signed out in another tab or window. Reload to refresh your session.

# %%
# 已登入有權限時
cookies = {'user_session': 'tuexze3Lu4Cy2Bz7feQ6pxi1yFJkLLQZs2......'} #<<<要刪除
res = requests.get('https://github.com/new', verify=False, cookies=cookies)
soup = BeautifulSoup(res.text,'html.parser')
print(*(x for x in list(filter(None, [x.strip() for x in soup.text.split('\n') if x]))), sep='\n')
# Out:
# Sign in to GitHub · GitHub
# Skip to content
# GitHub no longer supports this web browser.
# Learn more about the browsers we support.
# Sign in to GitHub
# Username or email address
# Password Forgot password?
# New to GitHub?
# Create an account.
# Terms
# Privacy
# Security
# Contact GitHub
# You can’t perform that action at this time.
# You signed in with another tab or window. Reload to refresh your session.
# You signed out in another tab or window. Reload to refresh your session.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://github.com/new'
resp = requests.get(url)
soup = BeautifulSoup(resp.text, 'html.parser')
print(soup.text.replace('\n',''))
# Out:
# Sign in to GitHub · GitHubSkip to contentGitHub no longer supports this web browser.          Learn more about the browsers we support.         Sign in to GitHub          Username or email address                  Password Forgot password?        New to GitHub?        Create an account.      TermsPrivacySecurityContact GitHub    You can’t perform that action at this time.  You signed in with another tab or window. Reload to refresh your session.You signed out in another tab or window. Reload to refresh your session.

# %%
cookies = {
    'logged_in':'yes',
    'user_session':'tuexze3Lu4Cy2Bz7feQ6pxi1yFJkLLQZs2tGJ.....x',
    'dotcom_user': 'ChenKuanHua',
    'has_recent_activity': '1',
}
resp = requests.get(url, verify=False, cookies=cookies) 
soup = BeautifulSoup(resp.text, 'html.parser')
print(soup.text.replace('\n',''))
# Out:
# Sign in to GitHub · GitHubSkip to contentGitHub no longer supports this web browser.          Learn more about the browsers we support.         Sign in to GitHub          Username or email address                  Password Forgot password?        New to GitHub?        Create an account.      TermsPrivacySecurityContact GitHub    You can’t perform that action at this time.  You signed in with another tab or window. Reload to refresh your session.You signed out in another tab or window. Reload to refresh your session.

# %%
print('1. 先到網站實際登入過後')
print('2. 找到登入前齁多出來的cookie')
print('3. 在模擬登入時加上那些cookie就可以了')
# Out:
# 1. 先到網站實際登入過後
# 2. 找到登入前齁多出來的cookie
# 3. 在模擬登入時加上那些cookie就可以了

# %%
import requests
from bs4 import BeautifulSoup
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}
cookies = {
    'unlock_ticket':'ABDuyUG7cRAmAAAAYAJVTf3VFl5E0me5XQXDCH2AmbNF-7zjo91UUQ==',
    'z_c0':'2|1:0|10:1578553077|4:z_c0|92:Mi4xa0VYeEZBQUFBQUFBSUtKLUFzcUVFQ1lBQUFCZ0FsVk45UndFWHdBOVh4Z3F6NVRTMHdYSjJkbldSdkM5Y3V2aFBn|bb271a4efdf87763a7079945ac28953229319e54192d25665259d7614c1c63e7'
}

# %%
res = requests.get('https://www.zhihu.com',headers=headers,cookies=cookies)
BeautifulSoup(res.text)
# Out:
# <!DOCTYPE html>
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 未授權前存取

res = requests.get('https://github.com/new')
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# Sign in to GitHub · GitHub
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
# GitHub no longer supports this web browser.
#
#           Learn more about the browsers we support.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sign in to GitHub
#
#
#
#
#
#
#
#
#
#
#           Username or email address
#
#
#
#           Password Forgot password?
#
#
#
#
#
#
#
#
#
#
#
#
#         New to GitHub?
#         Create an account.
#
#
#
#
#
#
# Terms
# Privacy
# Security
# Contact GitHub
#
#
#
#
#
#
#
#     You can’t perform that action at this time.
#
#
#
#
#
#
#
#
# You signed in with another tab or window. Reload to refresh your session.
# You signed out in another tab or window. Reload to refresh your session.

# %%
# 模仿授權
cookies = {'user_session': 'W7VpAgLcUouEd-m9Ql46l1O2_bFFRxT_DK4tG030OEtFUXT_'}
res = requests.get('https://github.com/new', cookies=cookies)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# Create a New Repository
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
# No suggested jump to results
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Pull requests
#
#
#     Issues
#
#
#
#         Marketplace
#
#
#
#     Explore
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   New repository
#
#
#     Import repository
#
#
#   New gist
#
#
#     New organization
#
#
#     New project
#
#
#
#
#
#
#
#
#
#
#
#
# Signed in as susan8213
#
#
#
#
#
#
#
#
#
#
#
#
#
# Set status
#
#
#
#
#
#
#
#
#
#
# Edit status
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
