# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
#
# * 根據範例使用 API 取出 高雄市小港區 2019 年 空氣品質 資料，並用一個適合的資料結構儲存
# * Hint: 將所有資料存在一個變數當中

# %%
import requests
url = 'https://taqm.epa.gov.tw/taqm/tw/MonthlyAverage.aspx'
payload = {
    '''
    Your Code
    '''
    'ctl05$ddlSite': 14,
    'ctl05$ddlYear': 2015,
    'ctl05$btnQuery': '查詢',
    'ScriptManager1': 'ctl05$UpdatePanel1|ctl05$btnQuery',
    '__VIEWSTATE': '...',
    '__VIEWSTATEGENERATOR': '0C858E1A',
    '__EVENTVALIDATION': '...'
}
r = requests.post(url, data=payload)
r.status_code
# Out:
# 200

# %% [markdown]
# ![](https://imgur.com/obLkbFe.jpg)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html.parser')
table = soup.find('table', class_='TABLE_G')
print(table)
# Out:
# <table align="Center" border="1" cellpadding="3" cellspacing="0" class="TABLE_G" id="ctl05_gv" rules="all" style="border-color:Black;border-width:1px;border-style:None;border-collapse:collapse;">
# <tr style="color:Black;font-weight:normal;">
# <th scope="col">監測項目</th><th scope="col">單位</th><th scope="col">監測日期</th><th scope="col">監測值</th><th scope="col">標註</th>
# </tr><tr style="color:Black;">
# <td class="no-alt" rowspan="12" style="white-space:nowrap;" valign="top">SO2</td><td class="no-alt" rowspan="12" valign="top">ppb</td><td>2015/01</td><td>2.60</td><td> </td>
# </tr><tr class="ALT" style="color:Black;">
# <td>2015/02</td><td>2.60</td><td> </td>
# </tr><tr style="color:Black;">
# <td>2015/03</td><td>2.40</td><td> </td>
# </tr><tr class="ALT" style="color:Black;">
# <td>2015/04</td><td>2.70</td><td> </td>
# </tr><tr style="color:Black;">
# <td>2015/05</td><td>3.10</td><td> </td>
# </tr><tr class="ALT" style="color:Black;">
# <td>2015/06</td><td>3</td><td> </td>
# ...

# %%
'''
Your Code
'''
# #==2=======
# d = {} #列表
# key = ''
# date = ''
# items = table.find_all('td')
# # print(items) #=====
# # <td class="no-alt" rowspan="12" style="white-space:nowrap;" valign="top">SO2</td>
# # <td class="no-alt" rowspan="12" valign="top">ppb</td>
# # <td>2019/01</td> <td>4.10</td> <td> </td>
# # <td>2019/02</td> <td>3.30</td> <td> </td>
# for item in items:
# #     print(item)
# #     print(item.attrs)
# #     <td class="no-alt" rowspan="12" style="white-space:nowrap;" valign="top">SO2</td>
# #     {'class': ['no-alt'], 'rowspan': '12', 'valign': 'top', 'style': 'white-space:nowrap;'}
# #     <td class="no-alt" rowspan="12" valign="top">ppb</td>
# #     {'class': ['no-alt'], 'rowspan': '12', 'valign': 'top'}
# #     <td>2019/01</td>
# #     {}
# #     <td>4.10</td>
# #     {}
# #     <td> </td>
# #     {}

#     if 'style' in item.attrs: #attrs字典
#         #attrs參數是dict類型，傳遞到Comment函數的時候前面加兩個星號轉成可變參數列表
#         #<td class="no-alt" rowspan="12" valign="top" style="white-space:nowrap;">SO2</td>
#         key = item.text
#         d[key]={} #表頭
#     elif 'class' not in item.attrs:
# #     <td>2019/01</td>
# #     {}
#         if item.text.strip() != '': #不等於空白
#         #strip() 方法用於移除字符串頭尾指定的字符（默認為空格或換行符）或字符序列。
#         #注意：該方法只能刪除開頭或是結尾的字符，不能刪除中間部分的字符。
#             # print(item.text)
#             if '/'in item.text: #日期
#                 date = item.text
#             else:
#                 # print(item.text)
#                 d[key][date] = item.text #資料
# # print(d)
# #==3=======
# items=[]
# monitor_items=[]

# trs=table.find_all('tr')
# for tr in trs:
# # <tr style="color:Black;"> #<<<5
# #    <td class="no-alt" rowspan="12" valign="top" style="white-space:nowrap;">SO2</td>
# #     <td class="no-alt" rowspan="12" valign="top">ppb</td>
# #     <td>2017/01</td>
# #     <td>2.20</td>
# #     <td>&nbsp;</td>
# # </tr>
# # <tr class="ALT" style="color:Black;">  #<<<3
# #  <td>2017/02</td>
# #     <td>2.40</td>
# #     <td>&nbsp;</td>
# # </tr>

# #     print(len(tr.find_all('td')))
#     tds=tr.find_all('td')
#     if len(tds)>0:
#         if len(tds)==5:
#             items.append(tds[0].text) #第一組 0監測項目,1單位, 2日期, 3監測值,
#             # append() 方法用於在列表末尾添加新的對象
# #             print(tds[3].text) #===
#             monitor_item={}
#             monitor_items.append(monitor_item)
#             monitor_item[tds[2].text]=tds[3].text
# #             print(tds[3].text) #=== 值
# #             print( monitor_item[tds[2].text]) #=== 值
#         if len(tds)==3: #日期
#             monitor_item[tds[0].text]=tds[1].text
# #             print(monitor_item[tds[0].text])
# #     print(monitor_item) #===
# #     print("====================") #===
# # print(monitor_items) #監測值
# # print(items) #監測項目
# # print("====================")
# d={}
# for item, monitor in zip(items, monitor_items):
#     #zip()函數用於將可迭代的對像作為參數，將對像中對應的元素打包成一個個元組，然後返回由這些元組組成的列表。
#     d[item]=monitor
# print(d)

#===3==========================
d = {}
for tr in table.find_all('tr')[1:]: #[1:]標題在 0 省略
# <tr style="color:Black;font-weight:normal;">
# <th scope="col">監測項目</th><th scope="col">單位</th><th scope="col">監測日期</th><th scope="col">監測值</th><th scope="col">標註</th>
# </tr>
    td = tr.find_all('td')
    if len(td) == 5:
        Head = td[0].text.strip()
        d[Head] ={}
        Date = td[2].text.strip()
        Value = td[3].text.strip()
        d[Head][Date] = Value
    elif len(td) == 3:
        Date = td[0].text.strip()
        Value = td[1].text.strip()
        d[Head][Date] = Value
# print(d)
d #直式顯示
# Out:
# {'SO2': {'2015/01': '2.60',
#   '2015/02': '2.60',
#   '2015/03': '2.40',
#   '2015/04': '2.70',
#   '2015/05': '3.10',
#   '2015/06': '3',
#   '2015/07': '3',
#   '2015/08': '2.70',
#   '2015/09': '',
#   '2015/10': '2.20',
#   '2015/11': '2.80',
#   '2015/12': '2.90'},
#  'CO': {'2015/01': '0.47',
#   '2015/02': '0.46',
#   '2015/03': '0.48',
#   '2015/04': '0.43',
#   '2015/05': '0.47',
#   '2015/06': '0.37',
#   '2015/07': '0.33',
#   '2015/08': '0.32',
#   '2015/09': '0.38',
#   '2015/10': '0.29',
#   '2015/11': '0.37',
#   '2015/12': '0.40'},
#  'O3': {'2015/01': '35.80',
#   '2015/02': '35.50',
#   '2015/03': '34.50',
#   '2015/04': '37',
#   '2015/05': '28.20',
#   '2015/06': '23.20',
#   '2015/07': '28.50',
#   '2015/08': '24.10',
#   '2015/09': '37.60',
#   '2015/10': '41.60',
#   '2015/11': '34.10',
#   '2015/12': '31.40'},
#  'PM10': {'2015/01': '49',
#   '2015/02': '46',
#   '2015/03': '39',
#   '2015/04': '38',
#   '2015/05': '34',
#   '2015/06': '34',
# ...

# %%
import pandas as pd
pd.DataFrame(d)
# Out:
#           SO2    CO     O3 PM10    NOx    NO    NO2  THC NMHC  CH4
# 2015/01  2.60  0.47  35.80   49  21.53  6.34  15.19  NaN  NaN  NaN
# 2015/02  2.60  0.46  35.50   46  20.10  4.49  15.60  NaN  NaN  NaN
# 2015/03  2.40  0.48  34.50   39  23.21  5.58  17.63  NaN  NaN  NaN
# 2015/04  2.70  0.43     37   38  19.23  3.18  16.05  NaN  NaN  NaN
# 2015/05  3.10  0.47  28.20   34  23.17  5.58  17.59  NaN  NaN  NaN
# 2015/06     3  0.37  23.20   34  19.57  4.14  15.42  NaN  NaN  NaN
# 2015/07     3  0.33  28.50   33  16.36  3.18  13.17  NaN  NaN  NaN
# 2015/08  2.70  0.32  24.10   26  16.13  3.40  12.73  NaN  NaN  NaN
# 2015/09        0.38  37.60   31  15.50  2.84  12.65  NaN  NaN  NaN
# 2015/10  2.20  0.29  41.60   34  10.93  1.81   9.11  NaN  NaN  NaN
# 2015/11  2.80  0.37  34.10   29  14.06  2.80  11.26  NaN  NaN  NaN
# 2015/12  2.90  0.40  31.40   36  15.82  3.07  12.74  NaN  NaN  NaN
#           NaN   NaN    NaN  NaN    NaN   NaN    NaN
